# %%
pip install pytest
# Out:
# ...
#
#    ------------- -------------------------- 1/3 [iniconfig]
#    -------------------------- ------------- 2/3 [pytest]
#    -------------------------- ------------- 2/3 [pytest]
#    -------------------------- ------------- 2/3 [pytest]
#    -------------------------- ------------- 2/3 [pytest]
#    -------------------------- ------------- 2/3 [pytest]
#    -------------------------- ------------- 2/3 [pytest]
#    -------------------------- ------------- 2/3 [pytest]
#    -------------------------- ------------- 2/3 [pytest]
#    -------------------------- ------------- 2/3 [pytest]
#    -------------------------- ------------- 2/3 [pytest]
#    -------------------------- ------------- 2/3 [pytest]
#    -------------------------- ------------- 2/3 [pytest]
#    -------------------------- ------------- 2/3 [pytest]
#    -------------------------- ------------- 2/3 [pytest]
#    ---------------------------------------- 3/3 [pytest]
#
# ...
